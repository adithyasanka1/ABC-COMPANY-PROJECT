# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
myexcel=pd.read_csv("myexcel-ABC company.csv")
myexcel
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# ## Replace incorrect data in the height coloumn with random numbers between 150 and 180

# %%
myexcel['Height'] = np.random.uniform(150,180,size=len(myexcel))
print("Modified 'Height' Column")
print(myexcel['Height'])
# Out:
# Modified 'Height' Column
# 0      177.177249
# 1      165.225485
# 2      158.410940
# 3      175.672923
# 4      169.935786
#           ...
# 453    151.904785
# 454    157.268404
# 455    163.740833
# 456    178.768250
# 457    161.611894
# Name: Height, Length: 458, dtype: float64

# %% [markdown]
# ## 1. How many are there in each team and the percentage splitting with respect to the Total Employees

# %%
team_count=myexcel['Team'].value_counts()
team_percentage=(team_count/len(myexcel))*100
team_summary=pd.DataFrame({'count':team_count,'percentage':team_percentage})
team_summary
# Out:
#                         count  percentage
# Team
# New Orleans Pelicans       19    4.148472
# Memphis Grizzlies          18    3.930131
# Utah Jazz                  16    3.493450
# New York Knicks            16    3.493450
# Milwaukee Bucks            16    3.493450
# Brooklyn Nets              15    3.275109
# Portland Trail Blazers     15    3.275109
# Oklahoma City Thunder      15    3.275109
# Denver Nuggets             15    3.275109
# Washington Wizards         15    3.275109
# Miami Heat                 15    3.275109
# Charlotte Hornets          15    3.275109
# Atlanta Hawks              15    3.275109
# San Antonio Spurs          15    3.275109
# Houston Rockets            15    3.275109
# Boston Celtics             15    3.275109
# Indiana Pacers             15    3.275109
# Detroit Pistons            15    3.275109
# Cleveland Cavaliers        15    3.275109
# Chicago Bulls              15    3.275109
# Sacramento Kings           15    3.275109
# ...

# %% [markdown]
# ## 2.Segregate the employees with respect to different posotions

# %%
position_count=myexcel['Position'].value_counts()
position_count
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %% [markdown]
# ## 3. Find from which age group most of the employees belong to

# %%
age=myexcel['Age'].value_counts
most_common_age=myexcel['Age'].mode()[0]
print("While comparing the age of employees,Most common age group is : ",most_common_age)
# Out:
# While comparing the age of employees,Most common age group is :  24

# %% [markdown]
# ## 4.Findout from which team and position, spending in terms of salary is high

# %%
high_salary_team_position=myexcel.groupby(['Team','Position'])['Salary'].mean()
spends_most=high_salary_team_position.idxmax()
spends_most
# Out:
# ('Memphis Grizzlies', 'C')

# %% [markdown]
# ## Find if there is any corelation between age and salary,represent it visually

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='Age',y='Salary',data=myexcel)
plt.title('Correlation between Age and Salary')
plt.show()

# %%
plt.bar(list(myexcel['Age'].value_counts().keys()),list(myexcel['Age'].value_counts()),color=['blue','red'])
plt.title("Correlation between Age and Salary")
plt.xlabel("Age")
plt.ylabel("Salary")
plt.show()
